# %%
import os
print('Hello from Fabric Spark!')
print('Lakehouse Files path exists:', os.path.exists('/lakehouse/default/Files'))
print('Medicare folder exists:', os.path.exists('/lakehouse/default/Files/medicare'))
medicare_files = os.listdir('/lakehouse/default/Files/medicare') if os.path.exists('/lakehouse/default/Files/medicare') else []
print('Files in medicare folder:', medicare_files)
# Out:
# StatementMeta(, 9cda0e52-e2bc-43f8-aa91-7a6e4a5b7155, 3, Finished, Available, Finished, False)
# Hello from Fabric Spark!
# Lakehouse Files path exists: True
# Medicare folder exists: True
# Files in medicare folder: ['Medicare_Part_D_Prescribers_by_Provider_and_Drug_Dataset_2013.zip', 'Medicare_Part_D_Prescribers_by_Provider_and_Drug_Dataset_2015.zip', 'raw']
